# %% [markdown]
# <a href="https://colab.research.google.com/github/ThuneGamma/C-CourseDesign/blob/master/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = "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" # Replace with your OpenRouter API key
SERPAPI_API_KEY = "c86ce74dadf59bc9b761433b499143e13b440ebc8c348452ff4ad8511668a6cb" # Replace with your SERPAPI API key
JINA_API_KEY = "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" # Replace with your JINA API key

# Endpoints
OPENROUTER_URL = "https://openrouter.ai/api/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "anthropic/claude-3.5-haiku"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: 湖北近三十年GDP发展
# Enter maximum number of iterations (default 10): 5
#
# === Iteration 1 ===
# Aggregated 30 unique links from this iteration.
# Fetching content from: https://m.gotohui.com/gdp/show-1630541
# Fetching content from: https://data.stats.gov.cn/easyquery.htm?cn=E0103
# Fetching content from: https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://gdp.gotohui.com/data-17
# Fetching content from: https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/
# Fetching content from: https://tjj.wuhan.gov.cn/tjfw/tjnj/202312/P020240228613247234803.pdf
# Fetching content from: http://tjj.shandong.gov.cn/art/2024/3/3/art_6196_10311526.html
# Fetching content from: https://icapcarbonaction.com/system/files/document/230417_ES_CHI.pdf
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273574.shtml
# Fetching content from: https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml
# Fetching content from: https://www.yicai.com/news/101704040.html
# Fetching content from: http://www.news.cn/fortune/20241128/d80ffcd3c9f94ee39d8b7f6bd0d955c6/c.html
# Fetching content from: https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf
# Fetching content from: https://finance.sina.cn/zl/2023-03-17/zl-imymcvnz4249797.d.html?from=wap
# Fetching content from: https://www.most.gov.cn/dfkj/hub/zxdt/202405/t20240510_190823.html
# Fetching content from: https://emcreative.eastmoney.com/app_fortune/article/index.html?artCode=20250105192638665541160&postId=1505739316
# Fetching content from: https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei
# Fetching content from: https://bg.qianzhan.com/report/detail/1811061602479505.html
# Fetching content from: http://jxt.hubei.gov.cn/bmdt/ttgz/202503/t20250301_5559409.shtml
# Fetching content from: https://www.gov.cn/2014lh/2013-09/02/content_2624232.htm
# Fetching content from: https://www.jrjingshan.com/a/baodao/2025/0302/67585.html
# Fetching content from: https://www.cenews.com.cn/news.html?aid=1196280
# Fetching content from: http://www.gd.gov.cn/xxts/content/post_4665923.html
# Fetching content from: https://www.shihang.org/zh/country/china
# Fetching content from: https://sjj.hubei.gov.cn/bmdt/tt/202503/t20250301_5559422.shtml
# Fetching content from: https://www.stats.gov.cn/hd/lyzx/zxgk/gdp/index_2.html
# Fetching content from: https://jingji.cctv.com/2024/11/01/ARTI0hGjwczoirydUaUPeleV241101.shtml
# Fetching content from: https://www.gov.cn/xinwen/2018-10/20/content_5332852.htm
# Jina fetch error for https://www.cenews.com.cn/news.html?aid=1196280: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.gd.gov.cn/xxts/content/post_4665923.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.yicai.com/news/101704040.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://gdp.gotohui.com/data-17: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.most.gov.cn/dfkj/hub/zxdt/202405/t20240510_190823.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://emcreative.eastmoney.com/app_fortune/article/index.html?artCode=20250105192638665541160&postId=1505739316: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stats.gov.cn/hd/lyzx/zxgk/gdp/index_2.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/xinwen/2018-10/20/content_5332852.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.gotohui.com/gdp/show-1630541: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://data.stats.gov.cn/easyquery.htm?cn=E0103: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.news.cn/fortune/20241128/d80ffcd3c9f94ee39d8b7f6bd0d955c6/c.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://icapcarbonaction.com/system/files/document/230417_ES_CHI.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/2014lh/2013-09/02/content_2624232.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.shihang.org/zh/country/china: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://bg.qianzhan.com/report/detail/1811061602479505.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://jxt.hubei.gov.cn/bmdt/ttgz/202503/t20250301_5559409.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://finance.sina.cn/zl/2023-03-17/zl-imymcvnz4249797.d.html?from=wap: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.shandong.gov.cn/art/2024/3/3/art_6196_10311526.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://jingji.cctv.com/2024/11/01/ARTI0hGjwczoirydUaUPeleV241101.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.wuhan.gov.cn/tjfw/tjnj/202312/P020240228613247234803.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.jrjingshan.com/a/baodao/2025/0302/67585.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://sjj.hubei.gov.cn/bmdt/tt/202503/t20250301_5559422.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273574.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['湖北省GDP年度详细数据', '湖北省GDP增长里程碑时期', '湖北省重点产业对GDP贡献', '湖北省GDP与全国GDP对比分析']
#
# === Iteration 2 ===
# Aggregated 33 unique links from this iteration.
# Fetching content from: https://data.stats.gov.cn/easyquery.htm?cn=E0103
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx
# Fetching content from: https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://gdp.gotohui.com/list/190024.html
# Fetching content from: https://news.hubeidaily.net/mobile/c_3579627.html
# Fetching content from: http://tjj.suizhou.gov.cn/fbjd_20/zwgk/xxgkml/tjsj/hbsndtjgb/202411/t20241127_1279033.shtml
# Fetching content from: https://www.taitra.org.tw/News_Content.aspx?n=104&s=97324
# Fetching content from: http://www.ciecworld.com/index.php?c=show&id=167
# Fetching content from: https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml
# Fetching content from: https://www.hubei.gov.cn/hbfb/xwfbh/202501/t20250122_5515065.shtml
# Fetching content from: https://swj.wuhan.gov.cn/tzdt/hykd/202401/t20240131_2353843.html
# Fetching content from: http://www.cppcc.gov.cn/zxww/2024/09/26/ARTI1727315895006197.shtml
# Fetching content from: https://m.thepaper.cn/wifiKey_detail.jsp?contid=2831822&from=wifiKey
# Fetching content from: https://view.inews.qq.com/a/20250204A04I2900?uid%5B0%5D=&uid%5B1%5D=
# Fetching content from: http://gxt.shandong.gov.cn/art/2025/2/28/art_15171_10348686.html
# Fetching content from: https://www.wuhan.gov.cn/sy/whyw/202401/t20240129_2351555.shtml
# Fetching content from: https://www.cq.gov.cn/ywdt/jrcq/202501/t20250121_14187721.html
# Fetching content from: https://www.jrjingshan.com/m/a/zt/ywjs/2025/0123/66707.html
# Fetching content from: https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf
# Fetching content from: https://www.cnis.ac.cn/ynbm/gjbzg/kydt/201710/t20171024_43074.html
# Fetching content from: http://whtb.mofcom.gov.cn/ztdy/art/2009/art_b48ea0fec64f4353a12abd23a795ec00.html
# Fetching content from: https://www.gov.cn/xinwen/2018-01/28/content_5261501.htm
# Fetching content from: https://www.ndrc.gov.cn/xwdt/gdzt/xyqqd/201712/t20171221_1197835.html
# Fetching content from: https://lkjjq.ezhou.gov.cn/ztzl/lkjjqhqzcfwzl/sj/zcwj/cy/202312/t20231201_596109.shtml
# Fetching content from: https://www.gov.cn/xinwen/2018-01/10/content_5255070.htm
# Fetching content from: http://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202001/t20200121_2013723.shtml
# Fetching content from: https://www.yicai.com/news/101704040.html
# Fetching content from: http://finance.people.com.cn/n1/2024/0131/c1004-40170326.html
# Fetching content from: https://www.ruralchina.cn/xcyj/SNChartDetail?SiteID=18&SubLibID=1932&ID=4900266
# Fetching content from: https://www.gov.cn/yaowen/liebiao/202405/content_6950201.htm
# Fetching content from: https://www.yicai.com/news/101048478.html
# Jina fetch error for https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.wuhan.gov.cn/sy/whyw/202401/t20240129_2351555.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ndrc.gov.cn/xwdt/gdzt/xyqqd/201712/t20171221_1197835.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.jrjingshan.com/m/a/zt/ywjs/2025/0123/66707.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.taitra.org.tw/News_Content.aspx?n=104&s=97324: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cnis.ac.cn/ynbm/gjbzg/kydt/201710/t20171024_43074.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://swj.wuhan.gov.cn/tzdt/hykd/202401/t20240131_2353843.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.yicai.com/news/101048478.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202001/t20200121_2013723.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.yicai.com/news/101704040.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.suizhou.gov.cn/fbjd_20/zwgk/xxgkml/tjsj/hbsndtjgb/202411/t20241127_1279033.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/xinwen/2018-01/10/content_5255070.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.hubei.gov.cn/hbfb/xwfbh/202501/t20250122_5515065.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://gxt.shandong.gov.cn/art/2025/2/28/art_15171_10348686.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.cppcc.gov.cn/zxww/2024/09/26/ARTI1727315895006197.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/xinwen/2018-01/28/content_5261501.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ruralchina.cn/xcyj/SNChartDetail?SiteID=18&SubLibID=1932&ID=4900266: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://view.inews.qq.com/a/20250204A04I2900?uid%5B0%5D=&uid%5B1%5D=: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://lkjjq.ezhou.gov.cn/ztzl/lkjjqhqzcfwzl/sj/zcwj/cy/202312/t20231201_596109.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/yaowen/liebiao/202405/content_6950201.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://news.hubeidaily.net/mobile/c_3579627.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://finance.people.com.cn/n1/2024/0131/c1004-40170326.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cq.gov.cn/ywdt/jrcq/202501/t20250121_14187721.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://gdp.gotohui.com/list/190024.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://whtb.mofcom.gov.cn/ztdy/art/2009/art_b48ea0fec64f4353a12abd23a795ec00.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.thepaper.cn/wifiKey_detail.jsp?contid=2831822&from=wifiKey: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://data.stats.gov.cn/easyquery.htm?cn=E0103: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.ciecworld.com/index.php?c=show&id=167: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['湖北省GDP三十年发展数据详细统计', '湖北省经济转型与GDP增长关系', '湖北省重要经济发展里程碑时期分析', '湖北省GDP年度变化与产业结构调整']
#
# === Iteration 3 ===
# Aggregated 33 unique links from this iteration.
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx
# Fetching content from: https://data.stats.gov.cn/easyquery.htm?cn=E0103
# Fetching content from: https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: http://tjj.hubei.gov.cn/ztzl/wqzl/tjkf/zjtj/201910/t20191025_21154.shtml
# Fetching content from: http://www.ciecworld.com/index.php?c=show&id=167
# Fetching content from: https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei
# Fetching content from: https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf
# Fetching content from: https://www.gov.cn/lianbo/bumen/202402/content_6934935.htm
# Fetching content from: https://www.stats.gov.cn/
# Fetching content from: http://jxt.hubei.gov.cn/bmdt/ttgz/202503/t20250301_5559409.shtml
# Fetching content from: http://zrzyt.hubei.gov.cn/bmdt/dtyw/202501/t20250120_5509809.shtml
# Fetching content from: https://yangtze.silkroadinfo.org.cn/2016/10/31/20161031105347.pdf
# Fetching content from: http://www.ddxyjj.com/scholarship_xiangxi.asp?i=21098
# Fetching content from: https://www.cnis.ac.cn/ynbm/gjbzg/kydt/201710/t20171024_43074.html
# Fetching content from: https://www.hanspub.org/journal/paperinformation?paperid=66356
# Fetching content from: https://www.caidian.gov.cn/zwgk/xxgkml/fzgh/sswgh/202203/t20220309_1935520.shtml
# Fetching content from: http://www.cppcc.gov.cn/zxww/2025/03/02/ARTI1740877635272173.shtml
# Fetching content from: http://www.prcee.org/xskw/jpwz/2020/2020_4/202009/W020201013494390934335.pdf
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202501/t20250122_5515003.shtml
# Fetching content from: https://tjj.hubei.gov.cn/bmdt/sjdt/202502/t20250217_5544460.shtml
# Fetching content from: http://www.hbsky.cn/c/2025/01/11/117243.shtml
# Fetching content from: http://www.xiangyang.gov.cn/2020/hqzc/sj/zcfb/202202/t20220209_2711194.shtml
# Fetching content from: http://www.sysdzz.cn/html/qkdd/2015/49241.html
# Fetching content from: https://wlj.wuhan.gov.cn/zfxxgk/fdzdgknr/ghxx/ssw/202111/t20211119_1854737.shtml
# Fetching content from: http://www.suizhou.gov.cn/ztfw/jiaoyu/xqjy/wjtz/202410/t20241023_1265080.shtml
# Fetching content from: https://jgxy.huat.edu.cn/info/1018/4658.htm
# Fetching content from: http://www.news.cn/fortune/20250224/21ab1b0684e94434b4e438f55cdf5ab8/c.html
# Fetching content from: https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml
# Fetching content from: https://www.stcn.com/article/detail/1534402.html
# Fetching content from: https://pdf.hanspub.org/ass20230500000_57754199.pdf
# Fetching content from: http://ckyk.cn/upload_files/20151105/4220392.pdf
# Fetching content from: https://xiaogan.gov.cn/zt/ztzl/zlmtkxg/zsmtbd/202209/t20220929_67990.shtml
# Jina fetch error for https://data.stats.gov.cn/easyquery.htm?cn=E0103: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.ciecworld.com/index.php?c=show&id=167: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://ckyk.cn/upload_files/20151105/4220392.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.sysdzz.cn/html/qkdd/2015/49241.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://wlj.wuhan.gov.cn/zfxxgk/fdzdgknr/ghxx/ssw/202111/t20211119_1854737.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stcn.com/article/detail/1534402.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stats.gov.cn/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-tw/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9B%BD%E5%86%85%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.ddxyjj.com/scholarship_xiangxi.asp?i=21098: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://xiaogan.gov.cn/zt/ztzl/zlmtkxg/zsmtbd/202209/t20220929_67990.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://yangtze.silkroadinfo.org.cn/2016/10/31/20161031105347.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.news.cn/fortune/20250224/21ab1b0684e94434b4e438f55cdf5ab8/c.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.hubei.gov.cn/ztzl/wqzl/tjkf/zjtj/201910/t20191025_21154.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cnis.ac.cn/ynbm/gjbzg/kydt/201710/t20171024_43074.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.cppcc.gov.cn/zxww/2025/03/02/ARTI1740877635272173.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://jgxy.huat.edu.cn/info/1018/4658.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pdf.hanspub.org/ass20230500000_57754199.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202501/t20250122_5515003.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://zrzyt.hubei.gov.cn/bmdt/dtyw/202501/t20250120_5509809.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.xiangyang.gov.cn/2020/hqzc/sj/zcfb/202202/t20220209_2711194.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/bmdt/sjdt/202502/t20250217_5544460.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.hanspub.org/journal/paperinformation?paperid=66356: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.suizhou.gov.cn/ztfw/jiaoyu/xqjy/wjtz/202410/t20241023_1265080.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.hbsky.cn/c/2025/01/11/117243.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://jxt.hubei.gov.cn/bmdt/ttgz/202503/t20250301_5559409.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/lianbo/bumen/202402/content_6934935.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.caidian.gov.cn/zwgk/xxgkml/fzgh/sswgh/202203/t20220309_1935520.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.prcee.org/xskw/jpwz/2020/2020_4/202009/W020201013494390934335.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['湖北省GDP近三十年具体年份数据', '湖北省GDP历年增长率详细分析', '湖北省经济发展重要拐点和政策影响', '湖北省GDP增长与武汉经济关系']
#
# === Iteration 4 ===
# Aggregated 36 unique links from this iteration.
# Fetching content from: https://data.stats.gov.cn/easyquery.htm?cn=E0103
# Fetching content from: https://m.gotohui.com/gdp/show-199749
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/
# Fetching content from: http://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/201911/t20191114_843094.shtml
# Fetching content from: https://www.stats.gov.cn/sj/zxfb/202407/t20240716_1955649.html
# Fetching content from: https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://documents1.worldbank.org/curated/en/158971468025142540/text/WPS34080CHINES1t011020040Poverty104.txt
# Fetching content from: https://www.most.gov.cn/zxgz/cxdc/cxdcpjbg/201710/P020171027320095787218.pdf
# Fetching content from: https://www.undp.org/sites/g/files/zskgke326/files/migration/cn/NHDR-CHN.pdf
# Fetching content from: https://www.cspengyuan.com/pengyuancmscn/rating-announcement/rating-infor/hubeizhengfu/20201014164407233/20201014164442645/20%E6%B9%96%E5%8C%97%E5%80%BA108.pdf
# Fetching content from: https://m.gotohui.com/gdp/show-1630626
# Fetching content from: http://www.ciecworld.com/index.php?c=show&id=167
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/index_125.shtml
# Fetching content from: https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202401/t20240126_5063989.shtml
# Fetching content from: https://tjj.sz.gov.cn/zmhd/zxft/fthg/content/post_11638008.html
# Fetching content from: http://czj.huangshi.gov.cn/2020xxgkzn/2020gknr/2020czzj/sbjyjs/202003/P020200324601825400270.pdf
# Fetching content from: https://www.stats.gov.cn/hd/cjwtjd/202302/t20230207_1902278.html
# Fetching content from: https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273574.shtml
# Fetching content from: https://www.bbc.com/zhongwen/trad/chinese-news-51868645
# Fetching content from: https://m.mof.gov.cn/czxw/202501/t20250116_3951813.htm
# Fetching content from: https://www.gov.cn/lianbo/difang/202405/content_6949643.htm
# Fetching content from: https://www.bbc.com/zhongwen/simp/chinese-news-51868645
# Fetching content from: https://wap.acfic.org.cn/qlgz/gdgsl/202501/t20250120_207959.html
# Fetching content from: https://nyxdhyj.isa.ac.cn/nyxdh/article/html/201602240274
# Fetching content from: http://www.xinhuanet.com/fortune/hgjj/zt1.htm
# Fetching content from: https://sjj.hubei.gov.cn/bmdt/tpxw/202501/t20250123_5517140.shtml
# Fetching content from: http://www.hb.chinanews.com.cn/news/2024/0219/402553.html
# Fetching content from: https://www.ctdsb.net/c1666_202502/2382043.html
# Fetching content from: https://www.stcn.com/article/detail/1534402.html
# Fetching content from: https://www.21jingji.com/article/20240720/herald/a86cadae8fc862f3736b778cd88b131d.html
# Fetching content from: https://www.wuhan.gov.cn/sy/whyw/202407/t20240720_2431207.shtml
# Fetching content from: https://m.21jingji.com/article/20231020/herald/fae744a84fd83d10b82cd76dda07e038.html
# Fetching content from: http://www.zgsuixian.gov.cn/ztzl_47/qszdtsg/202501/t20250123_1297728.shtml
# Fetching content from: https://www.joneslanglasalle.com.cn/zh/trends-and-insights/cities/wuhan-economic-rebound
# Jina fetch error for https://m.mof.gov.cn/czxw/202501/t20250116_3951813.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stcn.com/article/detail/1534402.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stats.gov.cn/hd/cjwtjd/202302/t20230207_1902278.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://sjj.hubei.gov.cn/bmdt/tpxw/202501/t20250123_5517140.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202401/t20240126_5063989.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.bbc.com/zhongwen/simp/chinese-news-51868645: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.21jingji.com/article/20240720/herald/a86cadae8fc862f3736b778cd88b131d.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.ciecworld.com/index.php?c=show&id=167: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.gotohui.com/gdp/show-1630626: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.hb.chinanews.com.cn/news/2024/0219/402553.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://documents1.worldbank.org/curated/en/158971468025142540/text/WPS34080CHINES1t011020040Poverty104.txt: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/201911/t20191114_843094.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.most.gov.cn/zxgz/cxdc/cxdcpjbg/201710/P020171027320095787218.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/index_125.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cspengyuan.com/pengyuancmscn/rating-announcement/rating-infor/hubeizhengfu/20201014164407233/20201014164442645/20%E6%B9%96%E5%8C%97%E5%80%BA108.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.gov.cn/lianbo/difang/202405/content_6949643.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ctdsb.net/c1666_202502/2382043.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/zh-hans/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.gotohui.com/gdp/show-199749: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://data.stats.gov.cn/easyquery.htm?cn=E0103: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273574.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.wuhan.gov.cn/sy/whyw/202407/t20240720_2431207.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stats.gov.cn/sj/zxfb/202407/t20240716_1955649.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://czj.huangshi.gov.cn/2020xxgkzn/2020gknr/2020czzj/sbjyjs/202003/P020200324601825400270.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.21jingji.com/article/20231020/herald/fae744a84fd83d10b82cd76dda07e038.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.undp.org/sites/g/files/zskgke326/files/migration/cn/NHDR-CHN.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://wap.acfic.org.cn/qlgz/gdgsl/202501/t20250120_207959.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.zgsuixian.gov.cn/ztzl_47/qszdtsg/202501/t20250123_1297728.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.joneslanglasalle.com.cn/zh/trends-and-insights/cities/wuhan-economic-rebound: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://nyxdhyj.isa.ac.cn/nyxdh/article/html/201602240274: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.sz.gov.cn/zmhd/zxft/fthg/content/post_11638008.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.xinhuanet.com/fortune/hgjj/zt1.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.bbc.com/zhongwen/trad/chinese-news-51868645: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['湖北省GDP年度详细数据1990-2023', '湖北省GDP历年变化趋势图表', '湖北省GDP分行业贡献详细分析', '湖北省重大经济事件对GDP影响']
#
# === Iteration 5 ===
# Aggregated 34 unique links from this iteration.
# Fetching content from: https://data.stats.gov.cn/easyquery.htm?cn=E0103
# Fetching content from: https://zh.wikipedia.org/wiki/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC
# Fetching content from: https://m.gotohui.com/gdp/show-1630541
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/
# Fetching content from: http://tjj.shandong.gov.cn/art/2024/3/3/art_6196_10311526.html
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjgb/ndtjgb/qstjgb/202403/t20240327_5135863.shtml
# Fetching content from: https://www.mfa.gov.cn/web/gjhdq_676201/gj_676203/yz_676205/1206_676884/
# Fetching content from: https://data.stats.gov.cn/publish.htm?sort=1
# Fetching content from: https://www.zhijiao.cn/news/detail/103149
# Fetching content from: https://gdp.gotohui.com/show-199738
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=
# Fetching content from: https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx
# Fetching content from: https://www.pishu.com.cn/skwx_ps//multimedia/ImageDetail?SiteID=14&type=ImageTable&ID=15102661&ContentType=MultimediaImageContentType
# Fetching content from: https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei
# Fetching content from: https://www.ydylcn.com/skwx_ydyl//competitiveReportDetail?SiteID=1&contentType=literature&subLibID=8730&mediaID=11606052
# Fetching content from: https://www.cenews.com.cn/news.html?aid=1196280
# Fetching content from: https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf
# Fetching content from: https://www.fmprc.gov.cn/zwbd_673032/wjzs/202502/t20250228_11565686.shtml
# Fetching content from: https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml
# Fetching content from: https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273559.shtml
# Fetching content from: https://www.stats.gov.cn/hd/cjwtjd/202302/t20230207_1902278.html
# Fetching content from: https://tjj.sz.gov.cn/zmhd/zxft/fthg/content/post_11638008.html
# Fetching content from: https://www.htsec.com/jfimg/colimg/upload/20210524/19041621820960009.pdf
# Fetching content from: https://m.21jingji.com/article/20231114/herald/fa4a4e2eccbe2bfafd785bf93bbc1e28.html
# Fetching content from: https://sjj.hubei.gov.cn/bmdt/tpxw/202501/t20250123_5517140.shtml
# Fetching content from: https://finance.eastmoney.com/a/202502113315942429.html
# Fetching content from: https://www.hubei.gov.cn/hbfb/xwfbh/202501/t20250122_5515065.shtml
# Fetching content from: https://m.21jingji.com/article/20250220/e4855a01d6116f7c032e835d8894c43e.html
# Fetching content from: http://www.ciecworld.com/index.php?c=show&id=167
# Fetching content from: https://news.sina.com.cn/zx/gj/2025-01-16/doc-inefczxz6281109.shtml
# Fetching content from: http://tjj.suizhou.gov.cn/fbjd_20/zwgk/xxgkml/tjsj/hbsndtjgb/202411/t20241127_1279033.shtml
# Fetching content from: https://tjj.wuhan.gov.cn/ztzl_49/xwfbh/202501/t20250126_2526274.shtml
# Fetching content from: http://news.cjn.cn/hbpd_19912/yw_19915/202502/t5091187.htm
# Fetching content from: https://www.stcn.com/article/detail/1197660.html
# Jina fetch error for https://www.pishu.com.cn/skwx_ps//multimedia/ImageDetail?SiteID=14&type=ImageTable&ID=15102661&ContentType=MultimediaImageContentType: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.gotohui.com/gdp/show-1630541: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.sz.gov.cn/zmhd/zxft/fthg/content/post_11638008.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://zh.wikipedia.org/wiki/%E6%B9%96%E5%8C%97%E7%9C%81%E5%9C%B0%E5%8C%BA%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://finance.eastmoney.com/a/202502113315942429.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://data.stats.gov.cn/publish.htm?sort=1: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.shandong.gov.cn/art/2024/3/3/art_6196_10311526.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.21jingji.com/article/20231114/herald/fa4a4e2eccbe2bfafd785bf93bbc1e28.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.mfa.gov.cn/web/gjhdq_676201/gj_676203/yz_676205/1206_676884/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.htsec.com/jfimg/colimg/upload/20210524/19041621820960009.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/SJKSH/sjksh.aspx: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ndrc.gov.cn/fggz/fzzlgh/dffzgh/202104/P020210427315108290779.pdf: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.wuhan.gov.cn/ztzl_49/xwfbh/202501/t20250126_2526274.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://research.hktdc.com/sc/data-and-profiles/mcpc/provinces/hubei: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://gdp.gotohui.com/show-199738: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.ydylcn.com/skwx_ydyl//competitiveReportDetail?SiteID=1&contentType=literature&subLibID=8730&mediaID=11606052: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://sjj.hubei.gov.cn/bmdt/tpxw/202501/t20250123_5517140.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/zfxxgk_GK2020/zc_GK2020/zcjd_GK2020/202501/t20250126_5520890.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.fmprc.gov.cn/zwbd_673032/wjzs/202502/t20250228_11565686.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/hbsj/Seach.aspx?pages=93&KeyWord=%E7%94%9F%E4%BA%A7%E6%80%BB%E5%80%BC&repp=&CycleId=: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://data.stats.gov.cn/easyquery.htm?cn=E0103: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://news.cjn.cn/hbpd_19912/yw_19915/202502/t5091187.htm: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.hubei.gov.cn/hbfb/xwfbh/202501/t20250122_5515065.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://tjj.suizhou.gov.cn/fbjd_20/zwgk/xxgkml/tjsj/hbsndtjgb/202411/t20241127_1279033.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjfx/qstjfx/202407/t20240719_5273559.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.zhijiao.cn/news/detail/103149: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://news.sina.com.cn/zx/gj/2025-01-16/doc-inefczxz6281109.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://tjj.hubei.gov.cn/tjsj/tjgb/ndtjgb/qstjgb/202403/t20240327_5135863.shtml: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stats.gov.cn/hd/cjwtjd/202302/t20230207_1902278.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://m.21jingji.com/article/20250220/e4855a01d6116f7c032e835d8894c43e.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cenews.com.cn/news.html?aid=1196280: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for http://www.ciecworld.com/index.php?c=show&id=167: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.stcn.com/article/detail/1197660.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['湖北GDP年度完整数据序列1990-2023', '湖北省GDP三十年增长数据统计报告', '湖北GDP发展关键时期和政策影响详细分析', '湖北经济发展与产业结构转型研究']
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# 报告标题：湖北省近三十年（约1990-2020）GDP发展历程与分析
#
# 一、总体发展概况
# 1. 经济规模持续增长
# • 1990年GDP规模较小，约千亿元量级
# • 2020年GDP突破4万亿元，增长近40倍
# • 年均增速保持在8-10%左右
#
# 二、重要发展阶段
# 1. 1990-2000年：初步工业化阶段
# • 经济年均增速约7-8%
# • 以传统制造业和农业为主
# • GDP规模从千亿级跃升到数千亿
#
# 2. 2000-2010年：加速转型期
# • 工业化和城镇化快速发展
# • GDP年均增速达到10-12%
# • 产业结构逐步优化
#
# 3. 2010-2020年：创新驱动阶段
# • 高新技术产业快速崛起
# • GDP年均增速8-9%
# • 武汉等城市成为创新中心
#
# 三、重点产业支撑
# 1. 汽车制造业
# 2. 光电子信息产业
# 3. 生物医药产业
# 4. 装备制造业
#
# 四、发展特点
# • 区域协调发展
# • 创新能力提升
# • 产业结构优化
#
# 五、未来发展展望
# • 继续推进创新驱动
# • 深化产业转型升级
# • 提高区域竞争力
#
# 结论：湖北省近三十年GDP实现跨越式发展,已从农业大省转变为现代化工业强省。
